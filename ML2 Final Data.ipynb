# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cruz = pd.read_csv("/content/listingscruz.csv")
denver = pd.read_csv("/content/listingsdenver.csv")
hi = pd.read_csv("/content/listingshi.csv")
la = pd.read_csv("/content/listingsla.csv")
nv = pd.read_csv("/content/listingsnv.csv")
oak = pd.read_csv("/content/listingsoak.csv")
pacifi = pd.read_csv("/content/listingspacifi.csv")
port = pd.read_csv("/content/listingsport.csv")
salem = pd.read_csv("/content/listingssalem.csv")
sc = pd.read_csv("/content/listingssc.csv")
sd = pd.read_csv("/content/listingssd.csv")
sf = pd.read_csv("/content/listingssf.csv")
sm = pd.read_csv("/content/listingssm.csv")
wa = pd.read_csv("/content/listingswa.csv")

# %%
data = pd.concat([cruz,denver,hi,la,nv,oak,pacifi,port,salem,sc,sd,sf,sm,wa])

# %%
data.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   8357   https://www.airbnb.com/rooms/8357  20220627154157   2022-06-27
# 1  11869  https://www.airbnb.com/rooms/11869  20220627154157   2022-06-27
# 2  11879  https://www.airbnb.com/rooms/11879  20220627154157   2022-06-27
# 3  24548  https://www.airbnb.com/rooms/24548  20220627154157   2022-06-27
# 4  31721  https://www.airbnb.com/rooms/31721  20220627154157   2022-06-27
#
#                                                 name  \
# 0  The Mushroom Dome Retreat & LAND of Paradise S...
# 1                            Cottage by the Redwoods
# 2                Sunny room close to beach and parks
# 3                        Room with Private Entrance.
# 4      Private Pleasure Point Beach Cottage w/hottub
#
#                                          description  \
# 0  Next available day is Aug. 28th, Next weekend:...
# 1  This is a very private cute cozy small bohemia...
# ...

# %%
data.shape
# Out:
# (131379, 74)

# %%
data.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
df = data[['id','host_id','name','description','neighborhood_overview','host_about','host_is_superhost']]

# %%
df.head()
# Out:
#       id  host_id                                               name  \
# 0   8357    24281  The Mushroom Dome Retreat & LAND of Paradise S...
# 1  11869    44764                            Cottage by the Redwoods
# 2  11879    44764                Sunny room close to beach and parks
# 3  24548    99532                        Room with Private Entrance.
# 4  31721   136376      Private Pleasure Point Beach Cottage w/hottub
#
#                                          description  \
# 0  Next available day is Aug. 28th, Next weekend:...
# 1  This is a very private cute cozy small bohemia...
# 2  Sunny room in a cozy home with a 40 acre park ...
# 3  Bedroom and bath with private entrance in my h...
# 4  *LOCATION LOCATION LOCATION* <br />Welcome to ...
#
#                                neighborhood_overview  \
# 0  Even though we live only a 8 minute drive to A...
# 1  This is a quiet neighborhood with no street li...
# 2                                                NaN
# ...

# %%
#save data to drive
df.to_csv('/content/drive/My Drive/ML2textdata.csv', index=False)

# %% [markdown]
# ## DUMP

# %%
#host_is_superhost is the target
data['host_is_superhost'].unique()
# Out:
# array(['t', 'f', nan], dtype=object)

# %%
data['target'] = data['host_is_superhost'].map({'t':1,'f':0,'nan':0})

# %%
data = data.drop('host_is_superhost', axis=1)

# %%
data.shape
# Out:
# (131379, 74)

# %%
data.head(5)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   8357   https://www.airbnb.com/rooms/8357  20220627154157   2022-06-27
# 1  11869  https://www.airbnb.com/rooms/11869  20220627154157   2022-06-27
# 2  11879  https://www.airbnb.com/rooms/11879  20220627154157   2022-06-27
# 3  24548  https://www.airbnb.com/rooms/24548  20220627154157   2022-06-27
# 4  31721  https://www.airbnb.com/rooms/31721  20220627154157   2022-06-27
#
#                                                 name  \
# 0  The Mushroom Dome Retreat & LAND of Paradise S...
# 1                            Cottage by the Redwoods
# 2                Sunny room close to beach and parks
# 3                        Room with Private Entrance.
# 4      Private Pleasure Point Beach Cottage w/hottub
#
#                                          description  \
# 0  Next available day is Aug. 28th, Next weekend:...
# 1  This is a very private cute cozy small bohemia...
# ...

# %%
data['target'].unique()
# Out:
# array([ 1.,  0., nan])
